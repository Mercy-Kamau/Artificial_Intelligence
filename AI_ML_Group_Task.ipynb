# %% [markdown]
# <a href="https://colab.research.google.com/github/Mercy-Kamau/Artificial_Intelligence/blob/main/AI_ML_Group_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
from numpy import array
from sklearn.preprocessing import Normalizer
from keras.activations import sigmoid
from keras.metrics import accuracy
from keras.losses import mse
from numpy.random import uniform

data={'Day 1':[30,40,50,20,15,60],'Day 2':[40,50,20,15,60,70],
 'Day 3':[50,20,15,60,70,50],'Target':[20,15,60,70,50,40]}
dataset=pd.DataFrame(data)
X=dataset.drop('Target',axis=1)
y=dataset['Target']
print(X)
X_norm = Normalizer(norm='max').fit_transform(X)
print(X_norm)
X_norm1=X_norm[0:4]
y_norm=Normalizer(norm='max').fit_transform(np.reshape(array(y),(1,-1)))
y_norm=np.transpose(y_norm)
print('ynorm {}'.format(y_norm[0][0:4]))
y_norm1=y_norm[0][0:4]

weight_1=uniform(-1,1,(3,2)) 
weight_2=uniform(-1,1,(2,1))
print('y_norm1 {}'.format(y_norm1))
y_true=y_norm1
# Defining results data frame
results = pd.DataFrame(columns=["mse"])


iterations=20
# Out:
# [[0.6        0.8        1.        ]
#  [0.8        1.         0.4       ]
#  [1.         0.4        0.3       ]
#  [0.33333333 0.25       1.        ]
#  [0.21428571 0.85714286 1.        ]
#  [0.85714286 1.         0.71428571]]
# ynorm [0.28571429]
# y_norm1 [0.28571429]

# %%
for itr in range(iterations):    
    
    # feedforward propagation
    # on hidden layer
    Z1 = np.dot(X_norm1, weight_1)
    A1 = sigmoid(Z1)
    print("A1 {}".format(A1))

    # on output layer
    Z2 = np.dot(A1, weight_2)
    A2 = sigmoid(Z2)
    print('A2 {}'.format(A2))
    
    
    # Calculating error
    mse_re= mse(A2, y_true)
   # acc = accuracy(A2, np.reshape(y_true,(-1,1)))
    results=results.append({"mse":mse_re},ignore_index=True )
    
    # backpropagation
    #𝑬𝒓𝒓𝒐𝒓 𝒌 = 𝒚-hat(𝒚) ∗ hat(𝒚)(𝟏-hat(y))
   # print('A2 {}'.format(A2))
    print('A1 {}'.format(A1))
    print('y_true {}'.format(y_true))
    E1 = A2 - y_true
    print('E1 {}'.format(E1))
    dW1 = E1 * A2 * (1 - A2)
    print('dw1 {}'.format(dW1))
    print('weight_2 {}'.format(weight_2))

    print("weight_2 repeated : {}".format(np.repeat(weight_2, repeats=2, axis=0)))
    E2 = np.dot(dW1, np.transpose(weight_2))
    
    print('E2 {}'.format(E2))
    dW2 = E2 * A1 * (1 - A1)

    
    # weight updates
                          
    W2_update = np.dot(np.transpose(A1), dW1) / y_true
    W1_update = np.dot(np.transpose(X_norm1), dW2) / y_true

    learning_rate=0.3
    #                                 change
    #current_weight=current_weight+(learning_rate*ErroratK*output)
    #                                                                 
    weight_2 = weight_2 + learning_rate * W2_update
    weight_1 = weight_1 + learning_rate * W1_update
# Out:
# A1 [[0.68468461 0.36292139]
#  [0.67178045 0.37270461]
#  [0.69598042 0.38412804]
#  [0.64158965 0.40446016]]
# A2 [[0.48749242]
#  [0.48866626]
#  [0.48814509]
#  [0.49191363]]
# A1 [[0.68468461 0.36292139]
#  [0.67178045 0.37270461]
#  [0.69598042 0.38412804]
#  [0.64158965 0.40446016]]
# y_true [0.28571429]
# E1 [[0.20177813]
#  [0.20295198]
#  [0.20243081]
#  [0.20619935]]
# dw1 [[0.05041297]
#  [0.05071192]
#  [0.05057925]
#  [0.05153635]]
# weight_2 [[-0.19281777]
#  [ 0.22588529]]
# weight_2 repeated : [[-0.19281777]
#  [-0.19281777]
#  [ 0.22588529]
#  [ 0.22588529]]
# E2 [[-0.00972052  0.01138755]
#  [-0.00977816  0.01145508]
#  [-0.00975258  0.01142511]
#  [-0.00993712  0.0116413 ]]
# A1 [[0.68160819 0.36705564]
#  [0.66894396 0.37648841]
#  [0.69382969 0.38715859]
#  [0.63938721 0.40735023]]
# A2 [[0.51981136]
#  [0.52068995]
#  [0.52120298]
#  [0.52341802]]
# A1 [[0.68160819 0.36705564]
#  [0.66894396 0.37648841]
#  [0.69382969 0.38715859]
#  [0.63938721 0.40735023]]
# y_true [0.28571429]
# E1 [[0.23409708]
#  [0.23497567]
#  [0.23548869]
#  [0.23770373]]
# dw1 [[0.05843239]
#  [0.05864333]
#  [0.05876631]
#  [0.05929558]]
# weight_2 [[-0.04912357]
#  [ 0.3072286 ]]
# weight_2 repeated : [[-0.04912357]
#  [-0.04912357]
#  [ 0.3072286 ]
#  [ 0.3072286 ]]
# E2 [[-0.00287041  0.0179521 ]
#  [-0.00288077  0.01801691]
#  [-0.00288681  0.01805469]
#  [-0.00291281  0.0182173 ]]
# A1 [[0.68069464 0.37362481]
#  [0.66810166 0.38249796]
#  [0.69319113 0.39196538]
#  [0.63873454 0.41192566]]
# A2 [[0.55714209]
#  [0.55766053]
#  [0.55932019]
#  [0.559735  ]]
# A1 [[0.68069464 0.37362481]
#  [0.66810166 0.38249796]
#  [0.69319113 0.39196538]
#  [0.63873454 0.41192566]]
# y_true [0.28571429]
# E1 [[0.27142781]
#  [0.27194625]
#  [0.2736059 ]
#  [0.27402071]]
# dw1 [[0.06697068]
#  [0.06708241]
#  [0.06743869]
#  [0.0675274 ]]
# weight_2 [[0.11650735]
#  [0.40218264]]
# weight_2 repeated : [[0.11650735]
#  [0.11650735]
#  [0.40218264]
#  [0.40218264]]
# E2 [[0.00780258 0.02693445]
#  [0.00781559 0.02697938]
#  [0.0078571  0.02712267]
#  [0.00786744 0.02715835]]
# A1 [[0.6831733  0.38360661]
#  [0.67038834 0.39162075]
#  [0.694925   0.39924748]
#  [0.64050594 0.41884258]]
# A2 [[0.59999953]
#  [0.60004666]
#  [0.60278207]
#  [0.60120026]]
# A1 [[0.6831733  0.38360661]
#  [0.67038834 0.39162075]
#  [0.694925   0.39924748]
#  [0.64050594 0.41884258]]
# y_true [0.28571429]
# E1 [[0.31428524]
#  [0.31433238]
#  [0.31706778]
#  [0.31548597]]
# dw1 [[0.07542849]
#  [0.07543684]
#  [0.07591739]
#  [0.07564045]]
# weight_2 [[0.30580601]
#  [0.51235987]]
# weight_2 repeated : [[0.30580601]
#  [0.30580601]
#  [0.51235987]
#  [0.51235987]]
# E2 [[0.02306648 0.03864653]
#  [0.02306904 0.03865081]
#  [0.02321599 0.03889703]
#  [0.0231313  0.03875513]]
# A1 [[0.69040314 0.39818929]
#  [0.67706836 0.4049287 ]
#  [0.69999377 0.40984074]
#  [0.64569282 0.42888013]]
# A2 [[0.64860114]
#  [0.64800399]
#  [0.65142748]
#  [0.64777786]]
# A1 [[0.69040314 0.39818929]
#  [0.67706836 0.4049287 ]
#  [0.69999377 0.40984074]
#  [0.64569282 0.42888013]]
# y_true [0.28571429]
# E1 [[0.36288685]
#  [0.36228971]
#  [0.36571319]
#  [0.36206357]]
# dw1 [[0.08270834]
#  [0.0826364 ]
#  [0.08304239]
#  [0.08260904]]
# weight_2 [[0.51927915]
#  [0.63885207]]
# weight_2 repeated : [[0.51927915]
#  [0.51927915]
#  [0.63885207]
#  [0.63885207]]
# E2 [[0.04294872 0.05283839]
#  [0.04291136 0.05279244]
#  [0.04312218 0.0530518 ]
#  [0.04289715 0.05277496]]
# A1 [[0.70346653 0.41859447]
#  [0.68917285 0.42351381]
#  [0.70919432 0.42458546]
#  [0.65514924 0.44281265]]
# A2 [[0.70229898]
#  [0.70084436]
#  [0.7041786 ]
#  [0.69861583]]
# A1 [[0.70346653 0.41859447]
#  [0.68917285 0.42351381]
#  [0.70919432 0.42458546]
#  [0.65514924 0.44281265]]
# y_true [0.28571429]
# E1 [[0.41658469]
#  [0.41513008]
#  [0.41846432]
#  [0.41290155]]
# dw1 [[0.0870975 ]
#  [0.08703681]
#  [0.08717076]
#  [0.08693714]]
# weight_2 [[0.75502705]
#  [0.78150398]]
# weight_2 repeated : [[0.75502705]
#  [0.75502705]
#  [0.78150398]
#  [0.78150398]]
# E2 [[0.06576097 0.06806704]
#  [0.06571515 0.06801961]
#  [0.06581628 0.0681243 ]
#  [0.0656399  0.06794172]]
# A1 [[0.72245813 0.4455911 ]
#  [0.70685251 0.44804978]
#  [0.72267958 0.44398931]
#  [0.66911661 0.46109227]]
# A2 [[0.75867377]
#  [0.75621004]
#  [0.75843951]
#  [0.7514276 ]]
# A1 [[0.72245813 0.4455911 ]
#  [0.70685251 0.44804978]
#  [0.72267958 0.44398931]
#  [0.66911661 0.46109227]]
# y_true [0.28571429]
# E1 [[0.47295949]
#  [0.47049575]
#  [0.47272522]
#  [0.46571331]]
# dw1 [[0.08659315]
#  [0.08673891]
#  [0.08660752]
#  [0.08698787]]
# weight_2 [[1.00706002]
#  [0.93777351]]
# weight_2 repeated : [[1.00706002]
#  [1.00706002]
#  [0.93777351]
#  [0.93777351]]
# E2 [[0.0872045  0.08120476]
#  [0.08735129 0.08134145]
#  [0.08721898 0.08121824]
#  [0.08760201 0.08157492]]
# A1 [[0.74578153 0.47866102]
#  [0.7287115  0.47805205]
#  [0.73945827 0.46767385]
#  [0.68668735 0.48333663]]
# A2 [[0.81304572]
#  [0.8096406 ]
#  [0.8099719 ]
#  [0.80224437]]
# A1 [[0.74578153 0.47866102]
#  [0.7287115  0.47805205]
#  [0.73945827 0.46767385]
#  [0.68668735 0.48333663]]
# y_true [0.28571429]
# E1 [[0.52733144]
#  [0.52392632]
#  [0.52425762]
#  [0.51653009]]
# dw1 [[0.08015563]
#  [0.08074894]
#  [0.08069238]
#  [0.08194664]]
# weight_2 [[1.26395938]
#  [1.10158478]]
# weight_2 repeated : [[1.26395938]
#  [1.26395938]
#  [1.10158478]
#  [1.10158478]]
# E2 [[0.10131346 0.08829822]
#  [0.10206338 0.0889518 ]
#  [0.10199189 0.0888895 ]
#  [0.10357723 0.09027117]]
# A1 [[0.77031619 0.5153707 ]
#  [0.7519046  0.51133254]
#  [0.7574363  0.49397681]
#  [0.70576947 0.50797283]]
# A2 [[0.85991689]
#  [0.85590555]
#  [0.85422301]
#  [0.84654684]]
# A1 [[0.77031619 0.5153707 ]
#  [0.7519046  0.51133254]
#  [0.7574363  0.49397681]
#  [0.70576947 0.50797283]]
# y_true [0.28571429]
# E1 [[0.5742026 ]
#  [0.57019126]
#  [0.56850873]
#  [0.56083255]]
# dw1 [[0.06916835]
#  [0.0703224 ]
#  [0.07079415]
#  [0.07285512]]
# weight_2 [[1.5102491 ]
#  [1.26361564]]
# weight_2 repeated : [[1.5102491 ]
#  [1.5102491 ]
#  [1.26361564]
#  [1.26361564]]
# E2 [[0.10446144 0.08740221]
#  [0.10620433 0.08886048]
#  [0.1069168  0.0894566 ]
#  [0.11002937 0.09206086]]
# A1 [[0.79291865 0.55205579]
#  [0.77347897 0.5446184 ]
#  [0.77437562 0.52041624]
#  [0.72401077 0.53268513]]
# A2 [[0.89605661]
#  [0.89186827]
#  [0.88867623]
#  [0.88157297]]
# A1 [[0.79291865 0.55205579]
#  [0.77347897 0.5446184 ]
#  [0.77437562 0.52041624]
#  [0.72401077 0.53268513]]
# y_true [0.28571429]
# E1 [[0.61034233]
#  [0.60615398]
#  [0.60296195]
#  [0.59585868]]
# dw1 [[0.05684677]
#  [0.05845704]
#  [0.0596515 ]
#  [0.06220888]]
# weight_2 [[1.73200722]
#  [1.41437943]]
# weight_2 repeated : [[1.73200722]
#  [1.73200722]
#  [1.41437943]
#  [1.41437943]]
# E2 [[0.09845902 0.0804029 ]
#  [0.10124802 0.08268044]
#  [0.10331683 0.08436985]
#  [0.10774623 0.08798696]]
# A1 [[0.81193374 0.58566607]
#  [0.79180637 0.57518676]
#  [0.78897409 0.54490463]
#  [0.73995112 0.55554387]]
# A2 [[0.92184822]
#  [0.91779872]
#  [0.91376368]
#  [0.90743408]]
# A1 [[0.81193374 0.58566607]
#  [0.79180637 0.57518676]
#  [0.78897409 0.54490463]
#  [0.73995112 0.55554387]]
# y_true [0.28571429]
# E1 [[0.63613394]
#  [0.63208444]
#  [0.6280494 ]
#  [0.62171979]]
# dw1 [[0.04582968]
#  [0.04768712]
#  [0.04949005]
#  [0.05222289]]
# weight_2 [[1.92260608]
#  [1.54815019]]
# weight_2 repeated : [[1.92260608]
#  [1.92260608]
#  [1.54815019]
#  [1.54815019]]
# E2 [[0.08811243 0.07095123]
#  [0.09168355 0.07382683]
#  [0.09514987 0.07661803]
#  [0.10040405 0.08084888]]
# A1 [[0.82724606 0.61484852]
#  [0.80669867 0.60182109]
#  [0.80100774 0.56647177]
#  [0.75325457 0.57566393]]
# A2 [[0.93969399]
#  [0.935935  ]
#  [0.93156465]
#  [0.92599979]]
# A1 [[0.82724606 0.61484852]
#  [0.80669867 0.60182109]
#  [0.80100774 0.56647177]
#  [0.75325457 0.57566393]]
# y_true [0.28571429]
# E1 [[0.6539797 ]
#  [0.65022072]
#  [0.64585037]
#  [0.64028551]]
# dw1 [[0.0370605 ]
#  [0.03898767]
#  [0.04117422]
#  [0.04387504]]
# weight_2 [[2.08289739]
#  [1.66391201]]
# weight_2 repeated : [[2.08289739]
#  [2.08289739]
#  [1.66391201]
#  [1.66391201]]
# E2 [[0.07719323 0.06166542]
#  [0.08120732 0.06487206]
#  [0.08576168 0.06851028]
#  [0.0913872  0.0730042 ]]
# A1 [[0.83946031 0.63959228]
#  [0.81867381 0.62449767]
#  [0.81081398 0.58504941]
#  [0.76421121 0.59299437]]
# A2 [[0.95209147]
#  [0.94866366]
#  [0.94425773]
#  [0.93936502]]
# A1 [[0.83946031 0.63959228]
#  [0.81867381 0.62449767]
#  [0.81081398 0.58504941]
#  [0.76421121 0.59299437]]
# y_true [0.28571429]
# E1 [[0.66637718]
#  [0.66294938]
#  [0.65854344]
#  [0.65365073]]
# dw1 [[0.03039567]
#  [0.03228624]
#  [0.03466248]
#  [0.03723089]]
# weight_2 [[2.21744376]
#  [1.7634851 ]]
# weight_2 repeated : [[2.21744376]
#  [2.21744376]
#  [1.7634851 ]
#  [1.7634851 ]]
# E2 [[0.06740068 0.0536023 ]
#  [0.07159293 0.05693631]
#  [0.0768621  0.06112677]
#  [0.0825574  0.06565612]]
# A1 [[0.84928597 0.66047201]
#  [0.82837546 0.64371684]
#  [0.8188541  0.60097968]
#  [0.77327552 0.60786004]]
# A2 [[0.9608935 ]
#  [0.9577845 ]
#  [0.95349584]
#  [0.94916792]]
# A1 [[0.84928597 0.66047201]
#  [0.82837546 0.64371684]
#  [0.8188541  0.60097968]
#  [0.77327552 0.60786004]]
# y_true [0.28571429]
# E1 [[0.67517922]
#  [0.67207021]
#  [0.66778155]
#  [0.66345363]]
# dw1 [[0.02537133]
#  [0.02717405]
#  [0.02961045]
#  [0.03201043]]
# weight_2 [[2.33137395]
#  [1.84954361]]
# weight_2 repeated : [[2.33137395]
#  [2.33137395]
#  [1.84954361]
#  [1.84954361]]
# E2 [[0.05915006 0.04692538]
#  [0.06335288 0.05025959]
#  [0.06903304 0.05476582]
#  [0.07462828 0.05920469]]
# A1 [[0.85731301 0.67817522]
#  [0.83635057 0.66008362]
#  [0.82553387 0.61469914]
#  [0.78086364 0.6206698 ]]
# A2 [[0.96731842]
#  [0.96449657]
#  [0.96039367]
#  [0.95653402]]
# A1 [[0.85731301 0.67817522]
#  [0.83635057 0.66008362]
#  [0.82553387 0.61469914]
#  [0.78086364 0.6206698 ]]
# y_true [0.28571429]
# E1 [[0.68160413]
#  [0.67878228]
#  [0.67467938]
#  [0.67081974]]
# dw1 [[0.02154789]
#  [0.0232435 ]
#  [0.02566323]
#  [0.02789046]]
# weight_2 [[2.42908418]
#  [1.92462133]]
# weight_2 repeated : [[2.42908418]
#  [2.42908418]
#  [1.92462133]
#  [1.92462133]]
# E2 [[0.05234164 0.04147153]
#  [0.05646042 0.04473493]
#  [0.06233815 0.049392  ]
#  [0.06774828 0.05367858]]
# A1 [[0.86398262 0.69331756]
#  [0.84301352 0.67414258]
#  [0.8311673  0.62660982]
#  [0.78730482 0.63179842]]
# A2 [[0.97214045]
#  [0.9695703 ]
#  [0.96567733]
#  [0.96220616]]
# A1 [[0.86398262 0.69331756]
#  [0.84301352 0.67414258]
#  [0.8311673  0.62660982]
#  [0.78730482 0.63179842]]
# y_true [0.28571429]
# E1 [[0.68642616]
#  [0.68385602]
#  [0.67996304]
#  [0.67649188]]
# dw1 [[0.01859075]
#  [0.0201763 ]
#  [0.02253712]
#  [0.02460094]]
# weight_2 [[2.51400557]
#  [1.99081525]]
# weight_2 repeated : [[2.51400557]
#  [2.51400557]
#  [1.99081525]
#  [1.99081525]]
# E2 [[0.04673726 0.03701076]
#  [0.05072334 0.04016729]
#  [0.05665845 0.04486725]
#  [0.0618469  0.04897593]]
# A1 [[0.86961451 0.70639969]
#  [0.84866739 0.68633839]
#  [0.83598771 0.63704502]
#  [0.79284737 0.64155595]]
# A2 [[0.97585332]
#  [0.97350166]
#  [0.96982063]
#  [0.96667389]]
# A1 [[0.86961451 0.70639969]
#  [0.84866739 0.68633839]
#  [0.83598771 0.63704502]
#  [0.79284737 0.64155595]]
# y_true [0.28571429]
# E1 [[0.69013903]
#  [0.68778738]
#  [0.68410635]
#  [0.68095961]]
# dw1 [[0.01626217]
#  [0.01774228]
#  [0.02002282]
#  [0.02193744]]
# weight_2 [[2.58873569]
#  [2.04977886]]
# weight_2 repeated : [[2.58873569]
#  [2.58873569]
#  [2.04977886]
#  [2.04977886]]
# E2 [[0.04209847 0.03333386]
#  [0.04593009 0.03636776]
#  [0.05183378 0.04104235]
#  [0.05679023 0.0449669 ]]
# A1 [[0.87443994 0.71781478]
#  [0.853533   0.69702145]
#  [0.84016724 0.64627069]
#  [0.79767656 0.65018943]]
# A2 [[0.97877789]
#  [0.97661561]
#  [0.97313809]
#  [0.97026471]]
# A1 [[0.87443994 0.71781478]
#  [0.853533   0.69702145]
#  [0.84016724 0.64627069]
#  [0.79767656 0.65018943]]
# y_true [0.28571429]
# E1 [[0.69306361]
#  [0.69090132]
#  [0.6874238 ]
#  [0.68455042]]
# dw1 [[0.01439613]
#  [0.0157785 ]
#  [0.0179695 ]
#  [0.01975004]]
# weight_2 [[2.65523323]
#  [2.10279792]]
# weight_2 repeated : [[2.65523323]
#  [2.65523323]
#  [2.10279792]
#  [2.10279792]]
# E2 [[0.03822508 0.03027215]
#  [0.0418956  0.033179  ]
#  [0.04771321 0.03778622]
#  [0.05244095 0.04153033]]
# A1 [[0.87862794 0.7278686 ]
#  [0.85777272 0.70646517]
#  [0.8438338  0.65449653]
#  [0.80193132 0.65789354]]
# A2 [[0.98112786]
#  [0.97913013]
#  [0.97584321]
#  [0.97320236]]
# A1 [[0.87862794 0.7278686 ]
#  [0.85777272 0.70646517]
#  [0.8438338  0.65449653]
#  [0.80193132 0.65789354]]
# y_true [0.28571429]
# E1 [[0.69541357]
#  [0.69341585]
#  [0.69012892]
#  [0.68748807]]
# dw1 [[0.01287627]
#  [0.01416948]
#  [0.01626858]
#  [0.01792937]]
# weight_2 [[2.71498615]
#  [2.15087336]]
# weight_2 repeated : [[2.71498615]
#  [2.71498615]
#  [2.15087336]
#  [2.15087336]]
# E2 [[0.03495889 0.02769522]
#  [0.03846994 0.03047675]
#  [0.04416896 0.03499165]
#  [0.04867798 0.03856379]]
# A1 [[0.88230389 0.7367994 ]
#  [0.86150761 0.71488323]
#  [0.84708363 0.66188798]
#  [0.80571695 0.6648218 ]]
# A2 [[0.98304916]
#  [0.98119508]
#  [0.9780844 ]
#  [0.97564321]]
# A1 [[0.88230389 0.7367994 ]
#  [0.86150761 0.71488323]
#  [0.84708363 0.66188798]
#  [0.80571695 0.6648218 ]]
# y_true [0.28571429]
# E1 [[0.69733488]
#  [0.6954808 ]
#  [0.69237012]
#  [0.68992893]]
# dw1 [[0.01162004]
#  [0.01283252]
#  [0.01484116]
#  [0.01639515]]
# weight_2 [[2.76913857]
#  [2.19479046]]
# weight_2 repeated : [[2.76913857]
#  [2.76913857]
#  [2.19479046]
#  [2.19479046]]
# E2 [[0.03217751 0.02550356]
#  [0.03553503 0.02816469]
#  [0.04109724 0.03257325]
#  [0.04540044 0.03598392]]

# %%
output_2=X_norm[5]@weight_1
#print('5th {}'.format(X_norm[5]))

act_output1=sigmoid(output_2).numpy()

pred_output1=act_output1@weight_2

print('actual result {}'.format(sigmoid(pred_output1)))
print("predicted result : {}".format(y_norm[5]))
#print(pred_output1)
# Out:
# actual result [0.98563096]
# predicted result : [0.57142857]
